# %%
# Import our dependencies
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the diabetes_data.csv.
import pandas as pd
diabetes_data_df = pd.read_csv('https://raw.githubusercontent.com/ComfyKoala/diabetes-classification/main/Stephen/diabetes_data.csv')
# Display the first few rows
diabetes_data_df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel  \
# 0       6000   44       0          1                    2               1
# 1       6001   51       1          0                    1               2
# 2       6002   89       1          0                    1               3
# 3       6003   21       1          1                    1               2
# 4       6004   27       1          0                    1               3
#
#          BMI  Smoking  AlcoholConsumption  PhysicalActivity  ...  \
# 0  32.985284        1            4.499365          2.443385  ...
# 1  39.916764        0            1.578919          8.301264  ...
# 2  19.782251        0            1.177301          6.103395  ...
# 3  32.376881        1            1.714621          8.645465  ...
# 4  16.808600        0           15.462549          4.629383  ...
#
#    TinglingHandsFeet  QualityOfLifeScore  HeavyMetalsExposure  \
# 0                  1           73.765109                    0
# 1                  0           91.445753                    0
# 2                  0           54.485744                    0
# 3                  0           77.866758                    0
# 4                  0           37.731808                    0
#
#    OccupationalExposureChemicals  WaterQuality  MedicalCheckupsFrequency  \
# 0                              0             0                  1.782724
# 1                              0             1                  3.381070
# 2                              0             0                  2.701019
# 3                              0             1                  1.409056
# 4                              0             0                  1.218452
#
#    MedicationAdherence  HealthLiteracy  Diagnosis  DoctorInCharge
# 0             4.486980        7.211349          1    Confidential
# 1             5.961705        5.024612          1    Confidential
# 2             8.950821        7.034944          0    Confidential
# 3             3.124769        4.717774          0    Confidential
# 4             6.977741        7.887940          0    Confidential
#
# [5 rows x 46 columns]

# %%
# List of all the columns in the data set
print(diabetes_data_df.columns)
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'SocioeconomicStatus',
#        'EducationLevel', 'BMI', 'Smoking', 'AlcoholConsumption',
#        'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'FamilyHistoryDiabetes', 'GestationalDiabetes',
#        'PolycysticOvarySyndrome', 'PreviousPreDiabetes', 'Hypertension',
#        'SystolicBP', 'DiastolicBP', 'FastingBloodSugar', 'HbA1c',
#        'SerumCreatinine', 'BUNLevels', 'CholesterolTotal', 'CholesterolLDL',
#        'CholesterolHDL', 'CholesterolTriglycerides',
#        'AntihypertensiveMedications', 'Statins', 'AntidiabeticMedications',
#        'FrequentUrination', 'ExcessiveThirst', 'UnexplainedWeightLoss',
#        'FatigueLevels', 'BlurredVision', 'SlowHealingSores',
#        'TinglingHandsFeet', 'QualityOfLifeScore', 'HeavyMetalsExposure',
#        'OccupationalExposureChemicals', 'WaterQuality',
#        'MedicalCheckupsFrequency', 'MedicationAdherence', 'HealthLiteracy',
#        'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %% [markdown]
# ## Drop Non-Beneficial Columns

# %%
# Drop the non-beneficial ID columns, 'PatientID' and 'DoctorInCharge'.
diabetes_data_clean_df = diabetes_data_df.drop(columns=['PatientID', 'DoctorInCharge'])

# %%
diabetes_data_clean_df
# Out:
#       Age  Gender  Ethnicity  SocioeconomicStatus  EducationLevel        BMI  \
# 0      44       0          1                    2               1  32.985284
# 1      51       1          0                    1               2  39.916764
# 2      89       1          0                    1               3  19.782251
# 3      21       1          1                    1               2  32.376881
# 4      27       1          0                    1               3  16.808600
# ...   ...     ...        ...                  ...             ...        ...
# 1874   37       0          0                    2               2  20.811137
# 1875   80       1          0                    2               2  27.694312
# 1876   38       1          0                    0               2  35.640824
# 1877   43       0          1                    2               0  32.423016
# 1878   85       1          0                    2               2  33.145119
#
#       Smoking  AlcoholConsumption  PhysicalActivity  DietQuality  ...  \
# 0           1            4.499365          2.443385     4.898831  ...
# 1           0            1.578919          8.301264     8.941093  ...
# 2           0            1.177301          6.103395     7.722543  ...
# 3           1            1.714621          8.645465     4.804044  ...
# 4           0           15.462549          4.629383     2.532756  ...
# ...       ...                 ...               ...          ...  ...
# 1874        0           10.946207          3.217636     8.338196  ...
# 1875        0           16.067905          7.107335     3.034771  ...
# 1876        0            4.865124          9.881212     2.657002  ...
# 1877        0            6.362936          4.750079     8.736024  ...
# 1878        0           13.854861          5.434137     5.127496  ...
#
#       SlowHealingSores  TinglingHandsFeet  QualityOfLifeScore  \
# 0                    0                  1           73.765109
# 1                    0                  0           91.445753
# 2                    0                  0           54.485744
# 3                    0                  0           77.866758
# 4                    0                  0           37.731808
# ...                ...                ...                 ...
# 1874                 0                  1           88.122729
# 1875                 1                  0           77.128599
# 1876                 0                  0           13.148221
# 1877                 0                  0           54.370980
# 1878                 0                  1           43.720860
#
#       HeavyMetalsExposure  OccupationalExposureChemicals  WaterQuality  \
# 0                       0                              0             0
# 1                       0                              0             1
# 2                       0                              0             0
# 3                       0                              0             1
# 4                       0                              0             0
# ...                   ...                            ...           ...
# 1874                    0                              0             1
# 1875                    0                              0             1
# 1876                    0                              0             0
# 1877                    0                              0             0
# 1878                    0                              0             1
#
#       MedicalCheckupsFrequency  MedicationAdherence  HealthLiteracy  Diagnosis
# 0                     1.782724             4.486980        7.211349          1
# 1                     3.381070             5.961705        5.024612          1
# 2                     2.701019             8.950821        7.034944          0
# 3                     1.409056             3.124769        4.717774          0
# 4                     1.218452             6.977741        7.887940          0
# ...                        ...                  ...             ...        ...
# 1874                  3.154225             3.849584        8.805087          0
# 1875                  0.424893             5.217465        0.915878          1
# 1876                  0.553757             3.377744        3.017481          1
# 1877                  1.132470             0.009250        4.914556          1
# 1878                  3.070583             8.483128        7.790921          1
#
# [1879 rows x 44 columns]

# %%
print(diabetes_data_clean_df.nunique())
# Out:
# Age                                71
# Gender                              2
# Ethnicity                           4
# SocioeconomicStatus                 3
# EducationLevel                      4
# BMI                              1879
# Smoking                             2
# AlcoholConsumption               1879
# PhysicalActivity                 1879
# DietQuality                      1879
# SleepQuality                     1879
# FamilyHistoryDiabetes               2
# GestationalDiabetes                 2
# PolycysticOvarySyndrome             2
# PreviousPreDiabetes                 2
# Hypertension                        2
# SystolicBP                         90
# DiastolicBP                        60
# FastingBloodSugar                1879
# HbA1c                            1879
# SerumCreatinine                  1879
# BUNLevels                        1879
# CholesterolTotal                 1879
# CholesterolLDL                   1879
# CholesterolHDL                   1879
# CholesterolTriglycerides         1879
# AntihypertensiveMedications         2
# Statins                             2
# AntidiabeticMedications             2
# FrequentUrination                   2
# ExcessiveThirst                     2
# UnexplainedWeightLoss               2
# FatigueLevels                    1879
# BlurredVision                       2
# SlowHealingSores                    2
# TinglingHandsFeet                   2
# QualityOfLifeScore               1879
# HeavyMetalsExposure                 2
# OccupationalExposureChemicals       2
# WaterQuality                        2
# MedicalCheckupsFrequency         1879
# MedicationAdherence              1879
# HealthLiteracy                   1879
# Diagnosis                           2
# dtype: int64

# %% [markdown]
# ## Identify Target (y) and Features (X)

# %%
# Split our preprocessed data into our features and target arrays
y = diabetes_data_clean_df["Diagnosis"]
X = diabetes_data_clean_df.drop(columns="Diagnosis")

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=10,
                                                    stratify=y)
X_train.shape
# Out:
# (1409, 43)

# %%
print(X_train.dtypes)
# Out:
# Age                                int64
# Gender                             int64
# Ethnicity                          int64
# SocioeconomicStatus                int64
# EducationLevel                     int64
# BMI                              float64
# Smoking                            int64
# AlcoholConsumption               float64
# PhysicalActivity                 float64
# DietQuality                      float64
# SleepQuality                     float64
# FamilyHistoryDiabetes              int64
# GestationalDiabetes                int64
# PolycysticOvarySyndrome            int64
# PreviousPreDiabetes                int64
# Hypertension                       int64
# SystolicBP                         int64
# DiastolicBP                        int64
# FastingBloodSugar                float64
# HbA1c                            float64
# SerumCreatinine                  float64
# BUNLevels                        float64
# CholesterolTotal                 float64
# CholesterolLDL                   float64
# CholesterolHDL                   float64
# CholesterolTriglycerides         float64
# AntihypertensiveMedications        int64
# Statins                            int64
# AntidiabeticMedications            int64
# FrequentUrination                  int64
# ExcessiveThirst                    int64
# UnexplainedWeightLoss              int64
# FatigueLevels                    float64
# BlurredVision                      int64
# SlowHealingSores                   int64
# TinglingHandsFeet                  int64
# QualityOfLifeScore               float64
# HeavyMetalsExposure                int64
# OccupationalExposureChemicals      int64
# WaterQuality                       int64
# MedicalCheckupsFrequency         float64
# MedicationAdherence              float64
# HealthLiteracy                   float64
# dtype: object

# %% [markdown]
# ## StandardScaler

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Neural Network #1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
n_features = X_train.shape[1]

nn = tf.keras.models.Sequential()

# First hidden layer with dropout
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=n_features))
nn.add(tf.keras.layers.Dropout(0.2))  # Adding a dropout layer with 20% dropout rate

# Second hidden layer with dropout
nn.add(tf.keras.layers.Dense(units=3, activation="sigmoid"))
nn.add(tf.keras.layers.Dropout(0.2))  # Another dropout layer

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 6)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              21 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 3)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               4 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 289 (1.13 KB)
#  Trainable params: 289 (1.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Create a callback that saves the model's weights every five epochs.
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='model_weights_epoch_{epoch:02d}.weights.h5',
    save_weights_only=True,
    save_freq=5 * (len(X_train_scaled) // 32)  # Save every 5 epochs (assuming batch size = 32)
)

# %%
# Early stopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # Can also use 'val_accuracy'
    patience=10,         # Wait for 10 epochs without improvement
    restore_best_weights=True
)

# Train the model with validation split and callbacks
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, batch_size=32,
                   validation_split=0.2, callbacks=[checkpoint_callback, early_stopping_callback])
# Out:
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.4610 - loss: 0.7186 - val_accuracy: 0.4504 - val_loss: 0.6982
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5076 - loss: 0.6958 - val_accuracy: 0.4929 - val_loss: 0.6875
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5051 - loss: 0.6931 - val_accuracy: 0.5390 - val_loss: 0.6799
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5507 - loss: 0.6826 - val_accuracy: 0.6135 - val_loss: 0.6733
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6076 - loss: 0.6715 - val_accuracy: 0.6206 - val_loss: 0.6672
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5891 - loss: 0.6697 - val_accuracy: 0.6277 - val_loss: 0.6612
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6137 - loss: 0.6691 - val_accuracy: 0.6206 - val_loss: 0.6560
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5891 - loss: 0.6638 - val_accuracy: 0.6206 - val_loss: 0.6505
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6520 - loss: 0.6516 - val_accuracy: 0.6277 - val_loss: 0.6443
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6093 - loss: 0.6516 - val_accuracy: 0.6348 - val_loss: 0.6378
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6393 - loss: 0.6395 - val_accuracy: 0.6489 - val_loss: 0.6301
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6475 - loss: 0.6388 - val_accuracy: 0.6525 - val_loss: 0.6216
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6737 - loss: 0.6176 - val_accuracy: 0.6773 - val_loss: 0.6113
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6858 - loss: 0.6090 - val_accuracy: 0.6986 - val_loss: 0.6003
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6995 - loss: 0.5970 - val_accuracy: 0.7199 - val_loss: 0.5880
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7205 - loss: 0.5801 - val_accuracy: 0.7376 - val_loss: 0.5737
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7148 - loss: 0.5754 - val_accuracy: 0.7624 - val_loss: 0.5594
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7295 - loss: 0.5687 - val_accuracy: 0.7695 - val_loss: 0.5451
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7397 - loss: 0.5523 - val_accuracy: 0.7837 - val_loss: 0.5309
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7686 - loss: 0.5397 - val_accuracy: 0.7837 - val_loss: 0.5176
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7468 - loss: 0.5356 - val_accuracy: 0.7979 - val_loss: 0.5052
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7861 - loss: 0.5056 - val_accuracy: 0.8227 - val_loss: 0.4938
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.7718 - loss: 0.4993 - val_accuracy: 0.8298 - val_loss: 0.4848
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7809 - loss: 0.4790 - val_accuracy: 0.8369 - val_loss: 0.4761
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7778 - loss: 0.4911 - val_accuracy: 0.8333 - val_loss: 0.4690
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7864 - loss: 0.4783 - val_accuracy: 0.8369 - val_loss: 0.4607
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7908 - loss: 0.4545 - val_accuracy: 0.8404 - val_loss: 0.4531
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7573 - loss: 0.4741 - val_accuracy: 0.8404 - val_loss: 0.4469
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7904 - loss: 0.4608 - val_accuracy: 0.8440 - val_loss: 0.4408
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8150 - loss: 0.4350 - val_accuracy: 0.8404 - val_loss: 0.4376
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8055 - loss: 0.4493 - val_accuracy: 0.8440 - val_loss: 0.4322
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7792 - loss: 0.4652 - val_accuracy: 0.8475 - val_loss: 0.4289
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8079 - loss: 0.4449 - val_accuracy: 0.8475 - val_loss: 0.4255
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7808 - loss: 0.4502 - val_accuracy: 0.8511 - val_loss: 0.4223
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7693 - loss: 0.4547 - val_accuracy: 0.8546 - val_loss: 0.4187
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7858 - loss: 0.4369 - val_accuracy: 0.8475 - val_loss: 0.4174
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8135 - loss: 0.4163 - val_accuracy: 0.8475 - val_loss: 0.4144
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7910 - loss: 0.4264 - val_accuracy: 0.8546 - val_loss: 0.4121
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7919 - loss: 0.4315 - val_accuracy: 0.8511 - val_loss: 0.4107
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8049 - loss: 0.4152 - val_accuracy: 0.8475 - val_loss: 0.4086
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7988 - loss: 0.4243 - val_accuracy: 0.8404 - val_loss: 0.4076
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8041 - loss: 0.4103 - val_accuracy: 0.8369 - val_loss: 0.4064
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8000 - loss: 0.4069 - val_accuracy: 0.8333 - val_loss: 0.4059
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8050 - loss: 0.4113 - val_accuracy: 0.8404 - val_loss: 0.4051
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7985 - loss: 0.4153 - val_accuracy: 0.8440 - val_loss: 0.4042
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8110 - loss: 0.3980 - val_accuracy: 0.8440 - val_loss: 0.4031
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7793 - loss: 0.4239 - val_accuracy: 0.8440 - val_loss: 0.4023
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8218 - loss: 0.3974 - val_accuracy: 0.8440 - val_loss: 0.4013
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8176 - loss: 0.3923 - val_accuracy: 0.8475 - val_loss: 0.4004
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7740 - loss: 0.4396 - val_accuracy: 0.8440 - val_loss: 0.4014
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8013 - loss: 0.4084 - val_accuracy: 0.8440 - val_loss: 0.4019
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7669 - loss: 0.4335 - val_accuracy: 0.8404 - val_loss: 0.4017
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7777 - loss: 0.4287 - val_accuracy: 0.8440 - val_loss: 0.4000
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8098 - loss: 0.3842 - val_accuracy: 0.8475 - val_loss: 0.3987
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7638 - loss: 0.4304 - val_accuracy: 0.8475 - val_loss: 0.3994
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8000 - loss: 0.4128 - val_accuracy: 0.8475 - val_loss: 0.3996
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8021 - loss: 0.3946 - val_accuracy: 0.8475 - val_loss: 0.3981
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7964 - loss: 0.3923 - val_accuracy: 0.8440 - val_loss: 0.3968
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7882 - loss: 0.3983 - val_accuracy: 0.8475 - val_loss: 0.3968
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8192 - loss: 0.3755 - val_accuracy: 0.8475 - val_loss: 0.3943
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7948 - loss: 0.3955 - val_accuracy: 0.8475 - val_loss: 0.3941
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8002 - loss: 0.3945 - val_accuracy: 0.8511 - val_loss: 0.3945
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8096 - loss: 0.3927 - val_accuracy: 0.8475 - val_loss: 0.3941
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8176 - loss: 0.4030 - val_accuracy: 0.8475 - val_loss: 0.3946
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7944 - loss: 0.4160 - val_accuracy: 0.8475 - val_loss: 0.3951
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7974 - loss: 0.4047 - val_accuracy: 0.8475 - val_loss: 0.3939
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8028 - loss: 0.3917 - val_accuracy: 0.8440 - val_loss: 0.3946
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7924 - loss: 0.3827 - val_accuracy: 0.8440 - val_loss: 0.3925
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7902 - loss: 0.3987 - val_accuracy: 0.8511 - val_loss: 0.3918
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8095 - loss: 0.3787 - val_accuracy: 0.8511 - val_loss: 0.3920
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8361 - loss: 0.3611 - val_accuracy: 0.8475 - val_loss: 0.3914
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7838 - loss: 0.4178 - val_accuracy: 0.8511 - val_loss: 0.3925
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7999 - loss: 0.3984 - val_accuracy: 0.8475 - val_loss: 0.3921
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7967 - loss: 0.3738 - val_accuracy: 0.8511 - val_loss: 0.3924
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7840 - loss: 0.4035 - val_accuracy: 0.8546 - val_loss: 0.3933
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8069 - loss: 0.3741 - val_accuracy: 0.8475 - val_loss: 0.3924
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8052 - loss: 0.3864 - val_accuracy: 0.8511 - val_loss: 0.3906
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7938 - loss: 0.4102 - val_accuracy: 0.8511 - val_loss: 0.3913
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8200 - loss: 0.3804 - val_accuracy: 0.8511 - val_loss: 0.3910
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8451 - loss: 0.3592 - val_accuracy: 0.8546 - val_loss: 0.3920
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8043 - loss: 0.3899 - val_accuracy: 0.8475 - val_loss: 0.3923
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8201 - loss: 0.3844 - val_accuracy: 0.8511 - val_loss: 0.3913
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8139 - loss: 0.3870 - val_accuracy: 0.8511 - val_loss: 0.3919
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8145 - loss: 0.3978 - val_accuracy: 0.8511 - val_loss: 0.3913
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8267 - loss: 0.3758 - val_accuracy: 0.8511 - val_loss: 0.3914
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8233 - loss: 0.3800 - val_accuracy: 0.8511 - val_loss: 0.3911
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8312 - loss: 0.3610 - val_accuracy: 0.8511 - val_loss: 0.3906
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8451 - loss: 0.3437 - val_accuracy: 0.8511 - val_loss: 0.3903
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7969 - loss: 0.3869 - val_accuracy: 0.8511 - val_loss: 0.3894
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8426 - loss: 0.3584 - val_accuracy: 0.8511 - val_loss: 0.3888
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8191 - loss: 0.3910 - val_accuracy: 0.8511 - val_loss: 0.3864
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8521 - loss: 0.3456 - val_accuracy: 0.8511 - val_loss: 0.3856
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8208 - loss: 0.4156 - val_accuracy: 0.8511 - val_loss: 0.3858
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8403 - loss: 0.3503 - val_accuracy: 0.8511 - val_loss: 0.3859
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8202 - loss: 0.3909 - val_accuracy: 0.8511 - val_loss: 0.3844
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8432 - loss: 0.3512 - val_accuracy: 0.8546 - val_loss: 0.3843
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8445 - loss: 0.3589 - val_accuracy: 0.8546 - val_loss: 0.3852
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8556 - loss: 0.3368 - val_accuracy: 0.8582 - val_loss: 0.3855
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8221 - loss: 0.3785 - val_accuracy: 0.8546 - val_loss: 0.3854
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8246 - loss: 0.3634 - val_accuracy: 0.8511 - val_loss: 0.3845

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 15/15 - 0s - 3ms/step - accuracy: 0.8085 - loss: 0.4048
# Loss: 0.4048275351524353, Accuracy: 0.8085106611251831

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss")
plt.show()

# %%
history_df.plot(y="accuracy")
plt.show()

# %% [markdown]
# # Weakest and Strongest Features

# %%
# !pip install scikeras scikit-learn
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.4.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
# !pip install --upgrade scipy scikit-learn scikeras
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.14.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.inspection import permutation_importance
import numpy as np

# Ensure that nn is defined as your Keras model

# Define the wrapped model (assuming nn is your Keras Sequential model)
wrapped_nn = KerasClassifier(model=nn, epochs=20, batch_size=32, verbose=0)

# Train the wrapped model
wrapped_nn.fit(X_train_scaled, y_train)

# Compute permutation importance
result = permutation_importance(wrapped_nn, X_test_scaled, y_test, n_repeats=10, random_state=10)

# Get feature importances
importances = result.importances_mean

# Ensure X_test_scaled is a DataFrame or convert it
if not isinstance(X_test_scaled, pd.DataFrame):
    X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# Sort the features by importance in ascending order (weakest to strongest)
sorted_indices = np.argsort(importances)

# Get the top 20 weakest features
top_20_weakest_indices = sorted_indices[:20]
top_20_weakest_features = X_test_scaled.columns[top_20_weakest_indices]
top_20_weakest_importances = importances[top_20_weakest_indices]

# Display the weakest features and their importances
for feature, importance in zip(top_20_weakest_features, top_20_weakest_importances):
    print(f"Weakest feature: {feature} with importance {importance}")
# Out:
# Weakest feature: Statins with importance -0.00957446808510638
# Weakest feature: WaterQuality with importance -0.005957446808510613
# Weakest feature: Smoking with importance -0.00574468085106381
# Weakest feature: MedicalCheckupsFrequency with importance -0.005531914893617007
# Weakest feature: BUNLevels with importance -0.004680851063829772
# Weakest feature: DietQuality with importance -0.004680851063829772
# Weakest feature: Ethnicity with importance -0.004042553191489351
# Weakest feature: CholesterolLDL with importance -0.003617021276595733
# Weakest feature: Gender with importance -0.0036170212765957222
# Weakest feature: AntihypertensiveMedications with importance -0.003404255319148919
# Weakest feature: SlowHealingSores with importance -0.0034042553191488967
# Weakest feature: SleepQuality with importance -0.0029787234042553123
# Weakest feature: EducationLevel with importance -0.002765957446808487
# Weakest feature: Age with importance -0.002765957446808476
# Weakest feature: CholesterolTriglycerides with importance -0.0025531914893616946
# Weakest feature: OccupationalExposureChemicals with importance -0.0025531914893616725
# Weakest feature: HealthLiteracy with importance -0.002127659574468055
# Weakest feature: FamilyHistoryDiabetes with importance -0.001489361702127634
# Weakest feature: PhysicalActivity with importance -0.0010638297872340274
# Weakest feature: MedicationAdherence with importance -0.0006382978723403987

# %%
# Define the wrapped model (assuming nn is your Keras Sequential model)
wrapped_nn = KerasClassifier(model=nn, epochs=20, batch_size=32, verbose=0)

# Train the wrapped model
wrapped_nn.fit(X_train_scaled, y_train)

# Compute permutation importance
result = permutation_importance(wrapped_nn, X_test_scaled, y_test, n_repeats=10, random_state=10)

# Get feature importances
importances = result.importances_mean

# Ensure X_test_scaled is a DataFrame or convert it
if not isinstance(X_test_scaled, pd.DataFrame):
    X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# Sort the features by importance in descending order (strongest to weakest)
sorted_indices = np.argsort(importances)[::-1]

# Get the top 20 strongest features
top_20_strongest_indices = sorted_indices[:20]
top_20_strongest_features = X_test_scaled.columns[top_20_strongest_indices]
top_20_strongest_importances = importances[top_20_strongest_indices]

# Display the strongest features and their importances
for feature, importance in zip(top_20_strongest_features, top_20_strongest_importances):
    print(f"Strongest feature: {feature} with importance {importance}")
# Out:
# Strongest feature: FastingBloodSugar with importance 0.18872340425531914
# Strongest feature: HbA1c with importance 0.1695744680851064
# Strongest feature: FrequentUrination with importance 0.0329787234042553
# Strongest feature: Hypertension with importance 0.020425531914893613
# Strongest feature: UnexplainedWeightLoss with importance 0.011063829787234025
# Strongest feature: TinglingHandsFeet with importance 0.009148936170212752
# Strongest feature: ExcessiveThirst with importance 0.00914893617021274
# Strongest feature: DiastolicBP with importance 0.008085106382978723
# Strongest feature: SystolicBP with importance 0.006595744680851024
# Strongest feature: FamilyHistoryDiabetes with importance 0.00638297872340422
# Strongest feature: BMI with importance 0.005957446808510625
# Strongest feature: GestationalDiabetes with importance 0.005531914893617007
# Strongest feature: QualityOfLifeScore with importance 0.005531914893616996
# Strongest feature: MedicationAdherence with importance 0.004468085106382957
# Strongest feature: CholesterolHDL with importance 0.004255319148936154
# Strongest feature: SocioeconomicStatus with importance 0.004255319148936132
# Strongest feature: CholesterolTriglycerides with importance 0.0038297872340425365
# Strongest feature: CholesterolTotal with importance 0.0031914893617020932
# Strongest feature: HealthLiteracy with importance 0.002765957446808498
# Strongest feature: SlowHealingSores with importance 0.0025531914893616725
